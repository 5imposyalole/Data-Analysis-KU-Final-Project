# %%
import pandas as pd

df = pd.read_csv('athlete_events.csv')

#df2 = pd.read_csv('athlete_events.csv')

#df.columns
#df['Season']
#print(df)
print(df.head(3))
#print(df.tail(3))

#df.loc[df['Season'] == 'Summer']
# Out:
#    ID                 Name Sex   Age  Height  Weight     Team  NOC  \
# 0   1            A Dijiang   M  24.0   180.0    80.0    China  CHN
# 1   2             A Lamusi   M  23.0   170.0    60.0    China  CHN
# 2   3  Gunnar Nielsen Aaby   M  24.0     NaN     NaN  Denmark  DEN
#
#          Games  Year  Season       City       Sport  \
# 0  1992 Summer  1992  Summer  Barcelona  Basketball
# 1  2012 Summer  2012  Summer     London        Judo
# 2  1920 Summer  1920  Summer  Antwerpen    Football
#
#                           Event Medal
# 0   Basketball Men's Basketball   NaN
# 1  Judo Men's Extra-Lightweight   NaN
# 2       Football Men's Football   NaN

# %%
import pandas as pd
df = pd.read_csv('athlete_events.csv')
#df2 = pd.read_csv('athlete_events.csv')

#average_age = df['Year'] == 2012 

new_df = df.loc[(df['Year'] == 2012)]

print(new_df)
# Out:
#             ID                                               Name Sex   Age  \
# 1            2                                           A Lamusi   M  23.0
# 98          34                 Jamale (Djamel-) Aarrass (Ahrass-)   M  30.0
# 134         48                                   Abdelhak Aatakni   M  24.0
# 164         67            Mariya Vasilyevna Abakumova (-Tarabina)   F  26.0
# 174         73                                          Luc Abalo   M  27.0
# 176         74                                   Mara Laura Abalo   F  30.0
# 197         91                                     Emanuele Abate   M  27.0
# 216        105                                       Ilyas Abbadi   M  19.0
# 249        123                                       Sohail Abbas   M  37.0
# 255        127                                     Shakeel Abbasi   M  28.0
# 256        128                                Soulmaz Abbasi Azad   F  28.0
# ...

# %%
import pandas as pd
df = pd.read_csv('athlete_events.csv')
#df2 = pd.read_csv('athlete_events.csv')

country = input('Enter Country name:\n')
year = int(input('Enter Year : \n'))
#season = input('Which Season?:\n')

years_summer = [1896, 1900, 1904, 1908, 1912, 1916, 1920, 1924, 1928, 1932, 1936, 1948, 1952, 1956, 1960, 1964, 1968, 1972, 1976, 1980, 1984, 1988, 1992, 1996, 2000, 2004, 2008, 2012, 2016]
years_winter = [1924, 1928, 1932, 1936, 1948, 1952, 1956, 1960, 1964, 1968, 1972, 1976, 1980, 1984, 1988, 1992, 1996, 2000, 2004, 2008, 2012, 2016]

s = len(years_summer)
w = len(years_winter)

data = []

df_1 = df.loc[(df['Team'] == country) & (df['Year'] >= year ) & (df['Season'] == 'Summer')]
print(df_1)


df_1['Age'].values.tolist()
age = df_1['Age'].values.tolist()
print (age)


for i in range(len(years_summer)):
    if year > years_summer[i]:
        x = years_summer[i+1:s]
        #new_year.append[x]
        


average_agef = []

for i in range(len(x)):
    #average_age = df['Year'] = x[i]
    average_age = df.loc[(df['Team'] == country)]
    
    

#print(len(years_summer))
#print('here')

#print(df['Age'])

#print(years_summer)
#print(years_winter)

#df.loc


#country = input()
#print('Please input a year greater than 1960: \n')
#year = input()
#[:,i]

#print(new_df[10])
#print(country)
#print(year)

#print('Which country are you interested in?: \n')
#a = input()
#print(a)
# Out:
# Enter Country name:
# China
# Enter Year :
# 2010
#             ID           Name Sex   Age  Height  Weight   Team  NOC  \
# 1            2       A Lamusi   M  23.0   170.0    60.0  China  CHN
# 2612      1464      Ai Yanhan   F  14.0   168.0    54.0  China  CHN
# 2613      1464      Ai Yanhan   F  14.0   168.0    54.0  China  CHN
# 12568     6847       Bai Anqi   F  19.0   164.0    59.0  China  CHN
# 12570     6849     Bai Faquan   M  26.0   173.0    66.0  China  CHN
# 12571     6849     Bai Faquan   M  30.0   173.0    66.0  China  CHN
# 14078     7598     Bao Yuqing   F  22.0   173.0    55.0  China  CHN
# 21256    11222   Bi Shengfeng   M  27.0   183.0    87.0  China  CHN
# 21294    11238        Bian Ka   F  23.0   182.0   115.0  China  CHN
# 33539    17300      Cai Zelin   M  21.0   175.0    55.0  China  CHN
# 33540    17300      Cai Zelin   M  25.0   175.0    55.0  China  CHN
# 34911    17994        Cao Hui   F  24.0   175.0    70.0  China  CHN
# ...

# %%
print('hello')
